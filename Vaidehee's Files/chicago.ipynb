# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
from scipy.stats import linregress
import json
import seaborn as sns
import calendar
import matplotlib.dates as mdates
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange

# %%
#reading data
crime_data = "/Users/Vaidehee/Desktop/chicago_data.csv"
# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(crime_data, encoding="utf-8")
df
# Out:
# /Users/Vaidehee/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,16,17,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         raw_row_number      date      time                         location  \
# 0                    1    1/6/12   9:00:00                    700 LINCOLN W
# 1                    2    1/1/12   0:00:00                              NaN
# 2                    3    1/1/12   1:00:00  0 NORTHWEST HWY & HILLSIDE RD S
# 3                    4    1/1/12   1:00:00                  108 LAMON AVE N
# 4                    5    1/1/12   1:00:00                  3451 177TH ST W
# ...                ...       ...       ...                              ...
# 846451          846452  12/23/16  12:00:00               4359 WOLCOTT AVE S
# 846452          846453   12/7/16  13:00:00           700 LAKE SHORE DR NB N
# 846453          846454  12/28/16   9:00:00               3904 CHICAGO AVE W
# 846454          846455  12/23/16  17:00:00          5400 LAKE SHORE DR NB N
# 846455          846456  12/22/16  10:00:00        10100 CHICAGO SKYWAY IB S
#
#               lat        lng  subject_age subject_race subject_sex  \
# 0             NaN        NaN         23.0        black        male
# 1             NaN        NaN         23.0     hispanic        male
# 2             NaN        NaN         38.0        white      female
# 3             NaN        NaN         35.0        black        male
# 4             NaN        NaN         20.0        black        male
# ...           ...        ...          ...          ...         ...
# 846451  41.814109 -87.672037          NaN          NaN      female
# 846452        NaN        NaN          NaN          NaN        male
# 846453  41.895682 -87.724031          NaN          NaN        male
# 846454        NaN        NaN          NaN          NaN        male
# 846455        NaN        NaN          NaN          NaN      female
#
#        officer_id_hash  ...  officer_race officer_sex  \
# 0           a6d791f976  ...         white        male
# 1           81da9fab7e  ...         white        male
# 2                  NaN  ...           NaN         NaN
# 3           048359e7c8  ...         black        male
# 4                  NaN  ...           NaN         NaN
# ...                ...  ...           ...         ...
# 846451             NaN  ...      hispanic        male
# 846452             NaN  ...         white        male
# 846453             NaN  ...         white        male
# 846454             NaN  ...         white        male
# 846455             NaN  ...      hispanic      female
#
#        officer_years_of_service       type  \
# 0                          17.0  vehicular
# 1                           2.0  vehicular
# 2                           NaN  vehicular
# 3                           8.0  vehicular
# 4                           NaN  vehicular
# ...                         ...        ...
# 846451                     10.0  vehicular
# 846452                     10.0  vehicular
# 846453                     16.0  vehicular
# 846454                     11.0  vehicular
# 846455                      2.0  vehicular
#
#                                         violation arrest_made citation_issued  \
# 0                    DRIVING ON SUSPENDED LICENSE        True             NaN
# 1                    DRIVING/NEVER ISSUED LICENSE        True             NaN
# 2                    DRIVING ON SUSPENDED LICENSE        True             NaN
# 3             IVC - FAIL TO STOP/SIGNAL CROSSWALK        True             NaN
# 4       IVC - DRIVING 15-20 MPH ABOVE SPEED LIMIT        True             NaN
# ...                                           ...         ...             ...
# 846451                 DOUBLE PARKING/NO STANDING         NaN            True
# 846452    DISOBEY RED CIRCULAR STEADY SIGNAL STOP         NaN            True
# 846453                      NO VALID REGISTRATION         NaN            True
# 846454  IVC - DRIVING 15-20 MPH ABOVE SPEED LIMIT         NaN            True
# 846455                SPEEDING 35+ MPH OVER LIMIT         NaN            True
#
#          outcome  raw_race raw_driver_race
# 0         arrest     BLACK             NaN
# 1         arrest  HISPANIC             NaN
# 2         arrest     WHITE             NaN
# 3         arrest     BLACK             NaN
# 4         arrest     BLACK             NaN
# ...          ...       ...             ...
# 846451  citation       NaN             NaN
# 846452  citation       NaN             NaN
# 846453  citation       NaN             NaN
# 846454  citation       NaN             NaN
# 846455  citation       NaN             NaN
#
# [846456 rows x 21 columns]

# %%
df.head()
# Out:
#    raw_row_number    date     time                         location  lat  lng  \
# 0               1  1/6/12  9:00:00                    700 LINCOLN W  NaN  NaN
# 1               2  1/1/12  0:00:00                              NaN  NaN  NaN
# 2               3  1/1/12  1:00:00  0 NORTHWEST HWY & HILLSIDE RD S  NaN  NaN
# 3               4  1/1/12  1:00:00                  108 LAMON AVE N  NaN  NaN
# 4               5  1/1/12  1:00:00                  3451 177TH ST W  NaN  NaN
#
#    subject_age subject_race subject_sex officer_id_hash  ...  officer_race  \
# 0         23.0        black        male      a6d791f976  ...         white
# 1         23.0     hispanic        male      81da9fab7e  ...         white
# 2         38.0        white      female             NaN  ...           NaN
# 3         35.0        black        male      048359e7c8  ...         black
# 4         20.0        black        male             NaN  ...           NaN
#
#   officer_sex officer_years_of_service       type  \
# 0        male                     17.0  vehicular
# 1        male                      2.0  vehicular
# 2         NaN                      NaN  vehicular
# 3        male                      8.0  vehicular
# 4         NaN                      NaN  vehicular
#
#                                    violation arrest_made citation_issued  \
# 0               DRIVING ON SUSPENDED LICENSE        True             NaN
# 1               DRIVING/NEVER ISSUED LICENSE        True             NaN
# 2               DRIVING ON SUSPENDED LICENSE        True             NaN
# 3        IVC - FAIL TO STOP/SIGNAL CROSSWALK        True             NaN
# 4  IVC - DRIVING 15-20 MPH ABOVE SPEED LIMIT        True             NaN
#
#   outcome  raw_race raw_driver_race
# 0  arrest     BLACK             NaN
# 1  arrest  HISPANIC             NaN
# 2  arrest     WHITE             NaN
# 3  arrest     BLACK             NaN
# 4  arrest     BLACK             NaN
#
# [5 rows x 21 columns]

# %%
df.count()
# Out:
# raw_row_number              846456
# date                        846456
# time                        846456
# location                    775414
# lat                         641014
# lng                         641014
# subject_age                 212223
# subject_race                224139
# subject_sex                 846121
# officer_id_hash             152584
# officer_age                  60063
# officer_race                786791
# officer_sex                 786791
# officer_years_of_service    784276
# type                        846455
# violation                   846455
# arrest_made                 212249
# citation_issued             639944
# outcome                     846456
# raw_race                    212249
# raw_driver_race              11906
# dtype: int64

# %%
list(df.columns)
# Out:
# ['raw_row_number',
#  'date',
#  'time',
#  'location',
#  'lat',
#  'lng',
#  'subject_age',
#  'subject_race',
#  'subject_sex',
#  'officer_id_hash',
#  'officer_age',
#  'officer_race',
#  'officer_sex',
#  'officer_years_of_service',
#  'type',
#  'violation',
#  'arrest_made',
#  'citation_issued',
#  'outcome',
#  'raw_race',
#  'raw_driver_race']

# %%
demo_df = df[['date', 'time', 'violation', 'arrest_made', 'citation_issued', 'outcome']]
demo_df.head()
# Out:
#      date     time                                  violation arrest_made  \
# 0  1/6/12  9:00:00               DRIVING ON SUSPENDED LICENSE        True
# 1  1/1/12  0:00:00               DRIVING/NEVER ISSUED LICENSE        True
# 2  1/1/12  1:00:00               DRIVING ON SUSPENDED LICENSE        True
# 3  1/1/12  1:00:00        IVC - FAIL TO STOP/SIGNAL CROSSWALK        True
# 4  1/1/12  1:00:00  IVC - DRIVING 15-20 MPH ABOVE SPEED LIMIT        True
#
#   citation_issued outcome
# 0             NaN  arrest
# 1             NaN  arrest
# 2             NaN  arrest
# 3             NaN  arrest
# 4             NaN  arrest

# %%
demo_df.count()
# Out:
# date               846456
# time               846456
# violation          846455
# arrest_made        212249
# citation_issued    639944
# outcome            846456
# dtype: int64

# %%
demo_df = demo_df.dropna()
demo_df.count()
# Out:
# date               5737
# time               5737
# violation          5737
# arrest_made        5737
# citation_issued    5737
# outcome            5737
# dtype: int64

# %%
print(demo_df.shape)
# Out:
# (5737, 6)

# %%
demo_df.time
demo_df.time.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 67        20:00:00
# 83        22:00:00
# 199        1:00:00
# 209        5:00:00
# 316       22:00:00
#             ...
# 211871    11:00:00
# 212022    17:00:00
# 212024    18:00:00
# 212040    21:00:00
# 212078     8:00:00
# Name: time, Length: 5737, dtype: object>

# %%
demo_df.dtypes
# Out:
# date               object
# time               object
# violation          object
# arrest_made        object
# citation_issued    object
# outcome            object
# dtype: object

# %%
#combine data and time column - sep by space store in space (object column) - convert to datatime format - to_datetime function
datetime = demo_df.date.str.cat(demo_df.time, sep= ' ')
datetime
# Out:
# 67          1/1/12 20:00:00
# 83          1/1/12 22:00:00
# 199          1/3/12 1:00:00
# 209          1/3/12 5:00:00
# 316         1/3/12 22:00:00
#                 ...
# 211871    12/28/16 11:00:00
# 212022    12/29/16 17:00:00
# 212024    12/29/16 18:00:00
# 212040    12/29/16 21:00:00
# 212078     12/30/16 8:00:00
# Name: date, Length: 5737, dtype: object

# %%
stop_datetime = pd.to_datetime(datetime)
result = stop_datetime.dt.hour
print(result)
# Out:
# 67        20
# 83        22
# 199        1
# 209        5
# 316       22
#           ..
# 211871    11
# 212022    17
# 212024    18
# 212040    21
# 212078     8
# Name: date, Length: 5737, dtype: int64

# %%
demo_df.dtypes
# Out:
# date               object
# time               object
# violation          object
# arrest_made        object
# citation_issued    object
# outcome            object
# dtype: object

# %%
#demo_df.set_index('stop_datetime', inplace=True)

# %%
demo_df['date'] = pd.to_datetime(demo_df['date'])
demo_df['year'] = demo_df['date'].dt.year

demo_df['month'] = demo_df['date'].dt.month
demo_df['day'] = demo_df['date'].dt.day

# %%
plt.figure(figsize=(10, 8))


demo_df.year.value_counts().sort_index().plot(kind = "bar", color='steelblue', alpha=0.5, align="center")

plt.title("Number of Stops Per Year", weight = 'bold', size=14)
plt.xlabel("Year", weight = 'bold', size=12)
plt.ylabel("Number of Stops", weight= 'bold', size=12)

plt.savefig("/Users/Vaidehee/Desktop/Number_of_Stops_Per_Year.png")

# %% [markdown]
# demo_df.month.value_counts().sort_index()
# demo_df['month'] = demo_df['month'].apply(lambda x: calendar.month_abbr[x])
#
#
#
# plt.figure(figsize=(10, 8))
#
# demo_df.month.value_counts().sort_index().plot(kind = "bar", color='r', alpha=0.5, align="center")
#
#
#
# plt.title("Number of Stops Per Month", weight = 'bold', size=14)
# plt.xlabel("Month", weight = 'bold', size=12)
# plt.ylabel("Number of Stops", weight= 'bold', size=12)
#
# demo_df['month'] = pd.to_datetime(demo_df['month'], format='%m').dt.month_name().str.slice(stop=3)

# %% [markdown]
# demo_df.day.value_counts().sort_index()
# plt.figure(figsize=(10, 8))
#
# demo_df.day.value_counts().sort_index().plot(kind = "bar", color='r', alpha=0.5, align="center")
#
#
# plt.title("Number of Stops Per Day", weight = 'bold', size=14)
# plt.xlabel("Day", weight = 'bold', size=12)
# plt.ylabel("Number of Stops", weight= 'bold', size=12)

# %%
sorted = time_count.reset_index()

sorted["index"] = pd.to_datetime(sorted["index"])

sorted = sorted.sort_values(by = 'index', ascending = True)

#sorted.set_index('index', inplace = True)


sorted
# Out:
#                  index  time
# 0  2021-04-05 00:00:00   199
# 11 2021-04-05 01:00:00   379
# 16 2021-04-05 02:00:00   310
# 17 2021-04-05 03:00:00   207
# 18 2021-04-05 04:00:00    72
# 19 2021-04-05 05:00:00    23
# 20 2021-04-05 06:00:00    28
# 21 2021-04-05 07:00:00    31
# 22 2021-04-05 08:00:00    58
# 23 2021-04-05 09:00:00    72
# 1  2021-04-05 10:00:00   147
# 2  2021-04-05 11:00:00   212
# 3  2021-04-05 12:00:00   199
# 4  2021-04-05 13:00:00   115
# 5  2021-04-05 14:00:00    85
# 6  2021-04-05 15:00:00   145
# 7  2021-04-05 16:00:00   168
# 8  2021-04-05 17:00:00   239
# 9  2021-04-05 18:00:00   434
# 10 2021-04-05 19:00:00   790
# 12 2021-04-05 20:00:00   530
# 13 2021-04-05 21:00:00   460
# 14 2021-04-05 22:00:00   461
# 15 2021-04-05 23:00:00   373

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange

fig,ax = plt.subplots(1)
fig.autofmt_xdate()
plt.plot(sorted['index'], sorted['time'])


ax.set_xlabel("Hour")
ax.set_ylabel("Number of Stops")
ax.set_title("Common Timepoint Stops")

ax.xaxis.set_major_formatter(mdates.DateFormatter('%H'))
ax.grid(linestyle='-', linewidth=1)
plt.show()

figsize=(10, 8)

fig.savefig("/Users/Vaidehee/Desktop/Common_Timepoint_Stops.png")
